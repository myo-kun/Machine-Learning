# %%
import csv
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import numpy as np
import pandas as pd 
sns.set()

# %%
train_data = pd.read_table("train.tsv")

# %%
test_data = pd.read_table("test.tsv")

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1169042 entries, 0 to 1169041
# Data columns (total 22 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   id      1169042 non-null  int64
#  1   click   1169042 non-null  int64
#  2   I1      1169042 non-null  int64
#  3   I2      1169042 non-null  int64
#  4   C1      1169042 non-null  int64
#  5   C2      1169042 non-null  int64
#  6   C3      1169042 non-null  int64
#  7   C4      1169042 non-null  int64
#  8   C5      1169042 non-null  int64
#  9   C6      1169042 non-null  int64
#  10  I3      1169042 non-null  int64
#  11  I4      1169042 non-null  int64
#  12  I5      1169042 non-null  int64
#  13  I6      1169042 non-null  int64
#  14  I7      1169042 non-null  int64
#  15  I8      1169042 non-null  int64
#  16  I9      1169042 non-null  int64
#  17  I10     1169042 non-null  int64
#  18  I11     981754 non-null   float64
#  19  I12     981754 non-null   float64
#  20  I13     981754 non-null   float64
#  21  I14     1129422 non-null  float64
# dtypes: float64(4), int64(18)
# memory usage: 196.2 MB

# %%
corr = train_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col1 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col3 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col4 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col5 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col6 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col7 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col8 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col9 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col10 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col11 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col12 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col13 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col14 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col15 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col16 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col17 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col18 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col19 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col20 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow0_col21 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col0 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col2 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col3 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col4 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col5 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col6 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col7 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col8 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col9 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col10 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col11 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col12 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col13 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col14 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col15 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col17 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col18 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col19 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col20 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow1_col21 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col1 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col3 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col4 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col5 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col6 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col7 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col8 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col9 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col10 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col11 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col12 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col13 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col14 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_97d2e2e4_c4c2_11ea_afd2_90cdb63e2fbarow2_col15 {
#             background-color:  #6b8df0;

# %%
train_data.isnull().sum()
# Out:
# id            0
# click         0
# I1            0
# I2            0
# C1            0
# C2            0
# C3            0
# C4            0
# C5            0
# C6            0
# I3            0
# I4            0
# I5            0
# I6            0
# I7            0
# I8            0
# I9            0
# I10           0
# I11      187288
# I12      187288
# I13      187288
# I14       39620
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer(strategy='mean')
imp.fit(train_data)
imputed_train_data = imp.transform(train_data)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-22-da4588c884b3> in <module>
#       1 imp = SimpleImputer(strategy='mean')
# ----> 2 imp.fit(train_data)
#       3 imputed_train_data = imp.transform(train_data)
#
# c:\users\mcken\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     275         self : SimpleImputer
#     276         """
# --> 277         X = self._validate_input(X, in_fit=True)
#     278         super()._fit_indicator(X)
#     279
#
# c:\users\mcken\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\impute\_base.py in _validate_input(self, X, in_fit)
#     242                                     accept_sparse='csc', dtype=dtype,
#     243                                     force_all_finite=force_all_finite,
# --> 244                                     copy=self.copy)
#     245         except ValueError as ve:
#     246             if "could not convert" in str(ve):
#
# c:\users\mcken\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# c:\users\mcken\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# c:\users\mcken\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     597                     array = array.astype(dtype, casting="unsafe", copy=False)
#     598                 else:
# --> 599                     array = np.asarray(array, order=order, dtype=dtype)
#     600             except ComplexWarning:
#     601                 raise ValueError("Complex data not supported\n"
#
# c:\users\mcken\appdata\local\programs\python\python36-32\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# c:\users\mcken\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1907
#    1908     def __array__(self, dtype=None) -> np.ndarray:
# -> 1909         return com.values_from_object(self)
#    1910
#    1911     def __array_wrap__(self, result, context=None):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.values_from_object()
#
# c:\users\mcken\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in values(self)
#    5485         """
#    5486         self._consolidate_inplace()
# -> 5487         return self._data.as_array(transpose=self._AXIS_REVERSED)
#    5488
#    5489     @property
#
# c:\users\mcken\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals\managers.py in as_array(self, transpose, items)
#     828             arr = np.asarray(mgr.blocks[0].get_values())
#     829         else:
# --> 830             arr = mgr._interleave()
#     831
#     832         return arr.transpose() if transpose else arr
#
# c:\users\mcken\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals\managers.py in _interleave(self)
#     846             dtype = "object"
#     847
# --> 848         result = np.empty(self.shape, dtype=dtype)
#     849
#     850         itemmask = np.zeros(self.shape[0])
#
# MemoryError: Unable to allocate 196. MiB for an array with shape (22, 1169042) and data type float64
